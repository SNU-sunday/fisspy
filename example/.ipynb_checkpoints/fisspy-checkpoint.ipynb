# %% [markdown]
# # FISSpy

# %% [markdown]
# #### The FISSpy is the data analysis tool for the [NST/FISS instrument](http://fiss.snu.ac.kr) based on The Python.
#
#
# website: http://fiss.snu.ac.kr
#
# code : https://github.com/SNU-sunday/FISS-PYTHON
#
# Email : jhkang@astro.snu.ac.kr
#
# ### Requirements
# * [NumPy](http://numpy.scipy.org/)
# * [Scipy](http://www.scipy.org/)
# * [Matplotlib](http://matplotlib.sourceforge.net/)
# * [Astropy](http://astropy.org)
# * [Interpolation](https://github.com/EconForge/interpolation.py)

# %% [markdown]
# # Setting

# %% [markdown]
# At first, we set up the notebook for inline plots.

# %%
# %matplotlib inline

# %% [markdown]
# Next, import some reuired packages.

# %%
import glob

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Header

# %%
import fisspy

# %%
cd "D:\github\SNU-sunday\Python-Learning\FISSpy_test"
# Out:
# D:\github\SNU-sunday\Python-Learning\FISSpy_test

# %%
file=glob.glob('*_c.fts')

# %%
header=fisspy.read.getheader(file[0])

# %%
print(header['NAXIS1'],header['naxis2'],header['NAXIS3'])
# Out:
# 512 256 130

# %%
header
# Out:
# PFILE   = 'FISS_20140603_164841_A1_p.fts'
# BSCALE  =           0.00117829
# SIMPLE  = 'T       '           /  file does conform to FITS standard
# BITPIX  =                   16 /  number of bits per data pixel
# NAXIS   =                    3 /  number of data axes
# NAXIS1  =                  512 /  length of data axis 1
# NAXIS2  =                  256 /  length of data axis 2
# NAXIS3  =                  130 /  length of data axis 3
# DATE    = '2014-06-03T16:48:41' /  file creation date (YYYY-MM-DDThh:mm:s
# EXPTIME =                 0.03 /  Second
# HBINNING=                    1
# VBINNING=                    2
# GAIN    =                    0 /  Value Range: 0-255
# STRTIME = '2014.06.03-16:48:24' /  Scan Start Time
# ENDTIME = '2014.06.03-16:48:41' /  Scan Finish Time
# ELAPTIME=             17.88445 /  Elapse Time During Scanning(Second)
# FISSMODE= 'Spectrograph'       /  FISS Mode
# STEPTIME=                130.0 /  1 Step Duration time(millisecond)
# STEPSIZE=         4.484155E-44 /  1 step size to move scanner(micrometer)
# CCDTEMP =                  -27 /  Cooling Temperature of CCD
# CCDNAME = 'DV897_BV'           /  Productname of CCD
# WAVELEN = '6562.8  '           /  CCD1 Wavenength(angstrom)
# CCD_XPIX=                  512 /  Full Pixel Size of X
# CCD_YPIX=                  512 /  Full Pixel Size of Y
# OBSERVER= 'Donguk Song'        /  The Name of Main Observer
# TARGET  = 'Sunspot '           /  Observation Target
# TEL_XPOS=                  134 /  X position of Telescope on the Sun
# TEL_YPOS=                 -318 /  Y position of Telescope on the Sun
# CRPIX1  =        259.848724365 /  pixel position of reference line center
# CDELT1  =      0.0191817938094 / angstrom per pixel
# CRVAL1  =             6562.817 / angstrom of reference line center
# HISTROY = 'processed by FISS_PREP'
# HISTORY dark+bias subtracted
# HISTORY flat-fieldded
# HISTORY -0.28 degree tilt corrected
# HISTORY displacement/distortion corrected

# %% [markdown]
# # Read spectrogram

# %% [markdown]
# Now, we read the fiss data.

# %%
datax=fisspy.read.frame(file[0],70)

# %%
datax.shape
# Out:
# (256, 512)

# %%
datax=datax.reshape((256,512))

# %%
plt.figure(figsize=(8,3))
plt.imshow(datax,cmap=fisspy.cm.ha,origin='lower')
plt.colorbar(ticks=np.arange(1000,8000,1000))

# %% [markdown]
# # Read raster image

# %%
raster=fisspy.read.raster(file[0],np.array([-5,-0.5,0,0.5]),0.05)

# %%
raster.shape
# Out:
# (256, 130, 4)

# %%
plt.figure(figsize=(5,5))
plt.imshow(raster[:,:,0],cmap=fisspy.cm.ha,origin='lower')
plt.colorbar()

# %%
plt.figure(figsize=(5,5))
plt.imshow(raster[:,:,2],cmap=fisspy.cm.ha,origin='lower')
plt.clim([1000,2300])
plt.colorbar()

# %% [markdown]
# # Doppler map

# %%
import fisspy.doppler

# %%
data=fisspy.read.frame(file[0],0,xmax=True)

# %%
data.shape
# Out:
# (130, 256, 512)

# %%
mdata=data.mean((0,1))

# %%
wv=fisspy.doppler.wavecalib('6562',mdata)

# %%
s=np.abs(wv)<=1.

# %%
wc, intensity=fisspy.doppler.lambdameter(wv[s],data[:,:,s],0.2)
# Out:
# Setting
# [33280   104]
# (33280, 104)

# %%
vel=wc*3e5/6562

# %%
plt.figure(figsize=(5,5))
plt.imshow(vel,origin='lower')
plt.clim([-2,2])
plt.colorbar(ticks=[-2,0,2])
